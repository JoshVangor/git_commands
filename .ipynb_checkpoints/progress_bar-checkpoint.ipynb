# %% [markdown]
# ![progress_bar.png](attachment:progress_bar.png)

# %% [markdown]
# # Building Progress Bars and Timeing Progress

# %% [markdown]
# ![developer.png](attachment:developer.png)

# %% [markdown]
# ## Step 0 - Import all the libraries your need - expecially github

# %%
first_install = False 
if first_install: 
    ! pip install tqdm

# %% [markdown]
# ## Optional Step 0 - Quickly explain the purpose of the project

# %%
import talking_code as tc 

talking_code = True
if talking_code:
    print("tqdm is a third party library that makes progress bars easy")           
    tc.say("tqdm is a third party library that makes progress bars easy")
else:     
    print("tqdm is a third party library that makes progress bars easy")
# Out:
# tqdm is a third party library that makes progress bars easy

# %%
from tqdm import tqdm
import time 

for item in tqdm([1,2,3,4,5]):
    time.sleep(0.3)
# Out:
# 100%|██████████| 5/5 [00:01<00:00,  3.21it/s]

# %%
for item in tqdm(range(10)):
    time.sleep(0.3)
# Out:
# 100%|██████████| 10/10 [00:03<00:00,  3.20it/s]

# %%
from tqdm import tqdm, trange
import time 

for item in tqdm(range(10)):
    time.sleep(0.3)
# Out:
# 100%|██████████| 10/10 [00:03<00:00,  3.23it/s]

# %%
! jupyter --version
# Out:
# Selected Jupyter core packages...
# IPython          : 8.8.0
# ipykernel        : 6.19.2
# ipywidgets       : 7.5.1
# jupyter_client   : 7.4.8
# jupyter_core     : 5.1.1
# jupyter_server   : 2.7.3
# jupyterlab       : 4.0.5
# nbclient         : 0.5.13
# nbconvert        : 7.2.9
# nbformat         : 5.7.0
# notebook         : 7.0.3
# qtconsole        : 5.4.0
# traitlets        : 5.7.1

# %%
upgrading_jupyter = False 
if upgrading_jupyter:
    ! pip install -U notebook

# %% [markdown]
# ## Step 1 -  run %timeit and %% timeit

# %% [markdown]
# # https://github.com/JoeEberle/
# # josepheberle@outlook.com

# %% [markdown]
# ![developer.png](attachment:developer.png)
